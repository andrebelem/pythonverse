# %% [markdown]
# <a href="https://colab.research.google.com/github/andrebelem/pythonverse/blob/main/PyGMT_0_17_0_GoogleColab_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### PyGMT 0.17 on Google Colab
#
# > ⚠️ **Note:** There’s a temporary pinning mismatch in Colab’s conda/mamba solver (the Python version in use is **3.12.11**, but the solver may carry a different internal pin).
# > Because of this, installing PyGMT requires using a compatible **condacolab** release (or aligning the conda `pinned` file to **python=3.12**).
# > After that, **PyGMT 0.17** installs and runs normally. This will be fixed in a future Colab update.

# %%
# !pip install condacolab --quiet
# need to install condacolab for a python 3.11 pin
import condacolab
condacolab.install_from_url("https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-Linux-x86_64.sh")
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %% [markdown]
# **Don't PANIC !** The kernel will restart automatically.
#
# After that, install `pygmt` normally.

# %%
# !mamba install pygmt --quiet # <--- it takes around 1 minute
# Out:
# warning  libmamba [numpy-2.3.3-py312h33ff503_0] The following files were already present in the environment:
#     - bin/f2py
#     - bin/numpy-config

# %%
import pygmt
pygmt.show_versions()
# Out:
# PyGMT information:
#   version: v0.17.0
# System information:
#   python: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
#   executable: /usr/bin/python3.real
#   machine: Linux-6.6.97+-x86_64-with-glibc2.35
# Dependency information:
#   numpy: 2.3.3
#   pandas: 2.3.3
#   xarray: 2025.9.1
#   packaging: 25.0
#   contextily: None
#   geopandas: 1.1.1
#   IPython: 7.34.0
#   pyarrow: 18.1.0
#   rioxarray: None
#   gdal: 3.11.0
#   ghostscript: 10.06.0
# GMT library information:
#   version: 6.5.0
#   padding: 2
#   share dir: /usr/local/share/gmt
#   plugin dir: /usr/local/lib/gmt/plugins
#   library path: /usr/local/lib/libgmt.so
#   cores: 2
#   grid layout: rows
#   image layout:
#   binary version: 6.5.0

# %%
# Just an example
from pygmt.datasets import load_earth_relief #<-- Use global relief for topography

grid = load_earth_relief(resolution='01d', registration='pixel')

fig = pygmt.Figure()
fig.basemap(region='g', projection='G330/-30/12c', frame=True)
fig.grdimage(grid, cmap='geo', shading=True)
fig.coast(resolution='c', shorelines=True, area_thresh=1000)
fig.plot(data='@hotspots.txt', style='c0.2c', fill='red')
fig.colorbar()
fig.show()
# Out:
# gmtread [NOTICE]: Remote data courtesy of GMT data server oceania [http://oceania.generic-mapping-tools.org]
# gmtread [NOTICE]: SRTM15 Earth Relief v2.7 at 1x1 arc degrees reduced by Gaussian Cartesian filtering (314.5 km fullwidth) [Tozer et al., 2019].
# gmtread [NOTICE]:   -> Download grid file [111K]: earth_relief_01d_p.grd

# %% [markdown]
# ### 🌊 Enjoy PyGMT 🌍
# Create stunning maps and figures directly from your **Colab notebook** —
# powered by **PyGMT 0.17.0**, **GMT**, and **Python 3.12**. Check out more examples at [**PyGMT External Resources**](https://www.pygmt.org/v0.17.0/external_resources.html).
#
# > _Happy mapping!_
